# %%
import openslide
import sys
from pathlib import Path
from PIL import Image
import matplotlib.pyplot as plt

# %%
he_path = Path(r"Datos\SB013\SB013\H&E\SB013.mrxs")

img = Image.open(he_path)

print("Formato:", img.format)
print("Tamaño:", img.size)
print("Modo:", img.mode)

plt.figure(figsize=(8, 12))
plt.imshow(img)
plt.axis("off")
plt.title("H&E preview (2D)")
plt.show()

# %%
hdr_path = Path(r"Datos\SB013\SB013\SB013_001\SB013_nrm.hdr")
print(hdr_path.read_text(encoding="utf-8", errors="ignore"))

# %%
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
from spectral import envi

base = Path(r"Datos")

hdr_matches = list(base.rglob("SB013_nrm.hdr"))
data_matches = list(base.rglob("SB013_nrm"))

print("HDR encontrados:")
for p in hdr_matches:
    print(" ", p)

print("\nDatos encontrados:")
for p in data_matches:
    print(" ", p)

hdr_path = hdr_matches[0]
data_path = data_matches[0]

img = envi.open(str(hdr_path), str(data_path))
cube = np.array(img.load(), dtype=np.float32)

print("\nShape del cubo:", cube.shape)
print("Metadata keys:", img.metadata.keys())

# %%
wavelengths = np.array([float(w) for w in img.metadata["wavelength"]])

print("Número de bandas:", len(wavelengths))
print("Primera banda:", wavelengths[0])
print("Última banda:", wavelengths[-1])

# %%
def nearest_band(target_nm, wavelengths):
    return int(np.argmin(np.abs(wavelengths - target_nm)))

b_idx = nearest_band(450, wavelengths)
g_idx = nearest_band(550, wavelengths)
r_idx = nearest_band(650, wavelengths)

print("Banda azul :", b_idx, wavelengths[b_idx])
print("Banda verde:", g_idx, wavelengths[g_idx])
print("Banda roja :", r_idx, wavelengths[r_idx])

rgb = cube[:, :, [r_idx, g_idx, b_idx]]

# %%
def percentile_stretch(rgb, p_low=2, p_high=98):
    out = np.zeros_like(rgb, dtype=np.float32)
    for c in range(3):
        band = rgb[:, :, c]
        lo, hi = np.percentile(band, [p_low, p_high])
        out[:, :, c] = np.clip((band - lo) / (hi - lo + 1e-8), 0, 1)
    return out

rgb_show = percentile_stretch(rgb)

plt.figure(figsize=(10, 8))
plt.imshow(rgb_show)
plt.axis("off")
plt.title("SB012 HSI false RGB")
plt.show()

# %%
hdr_path_2 = Path(r"Datos\SB013\SB013\SB013_2_001\SB013_2_nrm.hdr")
print(hdr_path_2.read_text(encoding="utf-8", errors="ignore"))

# %%
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
from spectral import envi

base = Path(r"Datos")

hdr_matches = list(base.rglob("SB013_2_nrm.hdr"))
data_matches = list(base.rglob("SB013_2_nrm"))

print("HDR encontrados:")
for p in hdr_matches:
    print(" ", p)

print("\nDatos encontrados:")
for p in data_matches:
    print(" ", p)

hdr_path_2 = hdr_matches[0]
data_path_2 = data_matches[0]

img_2 = envi.open(str(hdr_path_2), str(data_path_2))
cube_2 = np.array(img_2.load(), dtype=np.float32)

print("\nShape del cubo:", cube_2.shape)
print("Metadata keys:", img_2.metadata.keys())

# %%
wavelengths_2 = np.array([float(w) for w in img_2.metadata["wavelength"]])

print("Número de bandas:", len(wavelengths_2))
print("Primera banda:", wavelengths_2[0])
print("Última banda:", wavelengths_2[-1])

# %%
def nearest_band(target_nm, wavelengths):
    return int(np.argmin(np.abs(wavelengths - target_nm)))

b_idx = nearest_band(450, wavelengths_2)
g_idx = nearest_band(550, wavelengths_2)
r_idx = nearest_band(650, wavelengths_2)

print("Banda azul :", b_idx, wavelengths_2[b_idx])
print("Banda verde:", g_idx, wavelengths_2[g_idx])
print("Banda roja :", r_idx, wavelengths_2[r_idx])

rgb_2  = cube_2[:, :, [r_idx, g_idx, b_idx]]

# %%
def percentile_stretch(rgb, p_low=2, p_high=98):
    out = np.zeros_like(rgb, dtype=np.float32)
    for c in range(3):
        band = rgb[:, :, c]
        lo, hi = np.percentile(band, [p_low, p_high])
        out[:, :, c] = np.clip((band - lo) / (hi - lo + 1e-8), 0, 1)
    return out

rgb_show_2 = percentile_stretch(rgb_2)

plt.figure(figsize=(10, 8))
plt.imshow(rgb_show_2)
plt.axis("off")
plt.title("SB013_2 HSI false RGB")
plt.show()
